# %%
### DATA INGESTION ... Document data structure
from langchain_core.documents import Document

# %%
doc=Document(
    page_content="This is the main content written by Arya Jain",
    metadata={
        "source":"Example.txt",
        "page":1,
        "author":"ARYA JAIN",
        "date_created":"2026-04-01"
    }
)
doc
# Out:
# Document(metadata={'source': 'Example.txt', 'page': 1, 'author': 'ARYA JAIN', 'date_created': '2026-04-01'}, page_content='This is the main content written by Arya Jain')

# %%
import os 
os.makedirs("../data/text_files",exist_ok=True)

# %%
sample_text={
    "../data/text_files/pyhton_intro.txt":"""
    Python Programming Introduction

Python is a high-level, interpreted programming language known for its simplicity and readability.
Created by Guido van Rossum and first released in 1991, Python has become one of the most popular
programming languages in the world.

Key Features:
- Easy to learn and use with a clean, English-like syntax
- Extensive standard library and third-party packages (PyPI)
- Interpreted language — no compilation step needed
- Dynamically typed — variable types are assigned at runtime
- Supports multiple programming paradigms: procedural, OOP, and functional
- Cross-platform: runs seamlessly on Windows, macOS, and Linux
- Open-source with a large and active community

Common Use Cases:
- Data Science and Machine Learning (NumPy, Pandas, Scikit-learn, TensorFlow)
- Natural Language Processing and Generative AI (LangChain, Transformers, SpaCy)
- Web Development (Django, Flask, FastAPI)
- Automation and Scripting
- Scientific Computing and Research
- Data Visualization (Matplotlib, Seaborn, Plotly)

Basic Syntax Overview:
Python uses indentation to define code blocks instead of curly braces.
Variables do not require explicit type declarations.
Functions are defined using the 'def' keyword.
Classes support inheritance, encapsulation, and polymorphism.
Exception handling is done using try, except, else, and finally blocks.

Example:
    def greet(name):
        return f"Hello, {name}! Welcome to Python."

    print(greet("Arya"))

Why Python for Data Science and AI:
Python has emerged as the dominant language in the fields of Data Science,
Machine Learning, and Artificial Intelligence. Its rich ecosystem of libraries,
ease of prototyping, and strong community support make it the go-to choice for
researchers and engineers alike. Frameworks like LangChain, Hugging Face
Transformers, and Streamlit have further cemented Python's place in the
modern AI and GenAI landscape.

Getting Started:
To install Python, visit https://www.python.org/downloads/
Use pip to install packages: pip install <package_name>
Use virtual environments to manage dependencies: python -m venv myenv
Run scripts from terminal: python script.py
"""
    
}
for filepath,content in sample_text.items():
    with open(filepath,'w',encoding="utf-8") as f:
        f.write(content)
        
print("sample text files created!")
# Out:
# sample text files created!

# %%
### text loader to read the files

from langchain_community.document_loaders import TextLoader

loader=TextLoader("../data/text_files/pyhton_intro.txt",encoding="utf-8")
document=loader.load()
print(document)
# Out:
# [Document(metadata={'source': '../data/text_files/pyhton_intro.txt'}, page_content='\n    Python Programming Introduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\nCreated by Guido van Rossum and first released in 1991, Python has become one of the most popular\nprogramming languages in the world.\n\nKey Features:\n- Easy to learn and use with a clean, English-like syntax\n- Extensive standard library and third-party packages (PyPI)\n- Interpreted language — no compilation step needed\n- Dynamically typed — variable types are assigned at runtime\n- Supports multiple programming paradigms: procedural, OOP, and functional\n- Cross-platform: runs seamlessly on Windows, macOS, and Linux\n- Open-source with a large and active community\n\nCommon Use Cases:\n- Data Science and Machine Learning (NumPy, Pandas, Scikit-learn, TensorFlow)\n- Natural Language Processing and Generative AI (LangChain, Transformers, SpaCy)\n- Web Develop
# ...

# %%
from langchain_community.document_loaders import PyMuPDFLoader,PyPDFLoader,DirectoryLoader

dir_loader=DirectoryLoader(
    "../data/pdf",
    glob='**/*.pdf', ## pattern to mnatch this 
    loader_cls=PyMuPDFLoader,
    show_progress=False
)
 
pdf_documents=dir_loader.load()
pdf_documents
# Out:
# [Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-04-01T11:25:58+00:00', 'source': '..\\data\\pdf\\attention.pdf', 'file_path': '..\\data\\pdf\\attention.pdf', 'total_pages': 3, 'format': 'PDF 1.4', 'title': '(anonymous)', 'author': '(anonymous)', 'subject': '(unspecified)', 'keywords': '', 'moddate': '2026-04-01T11:25:58+00:00', 'trapped': '', 'modDate': "D:20260401112558+00'00'", 'creationDate': "D:20260401112558+00'00'", 'page': 0}, page_content="Attention Is All You Need\nAshish Vaswani, Noam Shazeer, Niki Parmar, Jakob Uszkoreit,\nLlion Jones, Aidan N. Gomez, Lukasz Kaiser, Illia Polosukhin\nGoogle Brain   |   Google Research   |   University of Toronto\nAbstract\nThe dominant sequence transduction models are based on complex recurrent or convolutional\nneural networks that include an encoder and a decoder. The best performing models also\nconnect the encoder and decoder through an attention mechanism. We pr
# ...

# %%
type(pdf_documents[0])
# Out:
# langchain_core.documents.base.Document
